# %%
# !find . -type f -size +5M
# Out:
# ./combined_code/best_steering_model_xy.pth
# ./combined_code/best_steering_model_xy.zip
# ./rail_following_sandbox/road_following_dataset_xy_2020-07-30_17-25-57.zip
# ./rail_following_sandbox/best_steering_model_xy.pth
# ./rail_following_sandbox/__archives__/best_steering_model_xy--BlueTapePoolCombo2.pth
# ./rail_following_sandbox/__archives__/best_steering_model_xy--BlueTapePoolDusk.pth
# ./rail_following_sandbox/__archives__/best_steering_model_xy--BlueTapePoolNight??.pth
# ./rail_following_sandbox/__archives__/best_steering_model_xy--BlueTapePoolCombo1.pth
# ./rail_following_sandbox/__archives__/best_steering_model_xy--BlueTapePoolDay.pth
# ./rail_following_sandbox/__archives__/best_steering_model_xy--TileFloor??.pth

# %%
#!ls -lR --block-size=MB

# %%
# !ls -lhRS
# Out:
# .:
# total 72K
# -rw-r--r-- 1 jetbot jetbot  22K Jul 27 12:32 GANTT_Autobus_Jul20.xlsx
# -rw-r--r-- 1 jetbot jetbot  16K Jul 30 18:16 files_check.ipynb
# -rw-r--r-- 1 jetbot jetbot 6.3K Jul 30 01:39 README.md
# -rw-r--r-- 1 jetbot jetbot 4.4K Jul 30 11:36 git_push.ipynb
# drwxr-xr-x 3 jetbot jetbot 4.0K Jul 30 18:15 combined_code
# drwxr-xr-x 5 jetbot jetbot 4.0K Jul 30 18:10 rail_following_sandbox
# -rw-r--r-- 1 jetbot jetbot 3.5K Jul 30 01:39 Report2.md
# -rw-r--r-- 1 jetbot jetbot 3.0K Jul 27 12:32 Report1.md
#
# ./combined_code:
# total 83M
# -rw-r--r-- 1 jetbot jetbot  43M Jul 30 18:13 best_steering_model_xy.pth
# -rw-r--r-- 1 jetbot jetbot  40M Jul 30 18:15 best_steering_model_xy.zip
# -rw-r--r-- 1 jetbot jetbot  18K Jul 30 18:10 AUTOBUS-Live.ipynb
# -rw-r--r-- 1 jetbot jetbot 2.3K Jul 30 17:40 Pseudocode_Algo.ipynb
#
# ./rail_following_sandbox:
# total 51M
# -rw-r--r-- 1 jetbot jetbot  43M Jul 30 17:50 best_steering_model_xy.pth
# ...
