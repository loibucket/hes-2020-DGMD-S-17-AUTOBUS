# %%
# !find . -type f -size +5M
# Out:
# ./combined_code/best_steering_model_xy--PoolTable400.pth
# ./combined_code/best_steering_model_xy--PoolTable400.pth.zip
# ./combined_code/best_obstacle_model--collision_avoidance_dataset.pth
# ./combined_code/collision_avoidance_dataset.zip
# ./combined_code/road_following_dataset_xy_2020-08-01_14-09-42--PoolTable400.zip
# ./combined_code/best_obstacle_model--NVIDIA.pth
# ./rail_following_waveshare/best_steering_model_xy--PoolTable400.pth
# ./rail_following_waveshare/best_steering_model_xy--PoolTable400.zip
# ./rail_following_waveshare/road_following_dataset_xy_2020-08-01_14-09-42--PoolTable400.zip
# ./rail_following_waveshare/__archives__/best_steering_model_xy--BlueTapePoolCombo2.pth
# ./rail_following_waveshare/__archives__/road_following_dataset_xy_2020-07-30_17-25-57--PoolTable300.zip
# ./rail_following_waveshare/__archives__/best_steering_model_xy--BlueTapePoolDusk.pth
# ./rail_following_waveshare/__archives__/best_steering_model_xy--BlueTapePoolNight??.pth
# ...

# %%
#!ls -lR --block-size=MB

# %%
# !ls -lhRS
# Out:
# .:
# total 208K
# -rwxr-xr-x 1 jetbot jetbot  88K Aug  2 22:02 camera_overrides.isp
# -rw-r--r-- 1 jetbot jetbot  50K Aug  1 23:38 files_check.ipynb
# -rw-r--r-- 1 jetbot jetbot  22K Jul 27 12:32 GANTT_Autobus_Jul20.xlsx
# -rw-r--r-- 1 jetbot jetbot  13K Aug  2 22:02 Camera_overrides.tar.gz
# -rw-r--r-- 1 jetbot jetbot 6.4K Aug  2 21:18 README.md
# drwxr-xr-x 4 jetbot jetbot 4.0K Aug  3 01:31 combined_code
# drwxr-xr-x 5 jetbot jetbot 4.0K Aug  1 14:11 rail_following_waveshare
# -rw-r--r-- 1 jetbot jetbot 3.5K Jul 30 01:39 Report2.md
# -rw-r--r-- 1 jetbot jetbot 3.0K Jul 27 12:32 Report1.md
# -rw-r--r-- 1 jetbot jetbot 2.7K Aug  3 01:33 git_push.ipynb
#
# ./combined_code:
# total 534M
# -rw-r--r-- 1 jetbot jetbot 218M Aug  1 22:17  best_obstacle_model--collision_avoidance_dataset.pth
# -rw-r--r-- 1 jetbot jetbot 218M Aug  1 22:36  best_obstacle_model--NVIDIA.pth
# -rw-r--r-- 1 jetbot jetbot  43M Jul 30 22:37  best_steering_model_xy--PoolTable400.pth
# ...
